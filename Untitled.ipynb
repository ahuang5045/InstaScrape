# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re
import os
import requests
from urllib.request import urlopen
import json
from pandas.io.json import json_normalize
import pandas as pd, numpy as np
import argparse
import csv
from typing import List
from requests_html import HTMLSession

# %%
soup = BeautifulSoup(requests.get('https://www.instagram.com/p/Bz8hdNKIxJG/').text, 'html.parser')
data = soup.find('meta', attrs={'property': 'og:description'})

# %%
data
# Out:
# <meta content="2,300 Likes, 21 Comments - @international_life_style on Instagram: “Yes or No? . . . 💄 #makeup #instamakeup #toptags #cosmetic #cosmetics #fashion #eyeshadow #lipstick…”" property="og:description">
# <meta content="124024574287414" property="fb:app_id">
# <meta content="https://www.instagram.com/p/Bz8hdNKIxJG/" property="og:url">
# <meta content="5039813798" property="instapp:owner_user_id"/>
# <meta content="Instagram" property="al:ios:app_name"/>
# <meta content="389801252" property="al:ios:app_store_id"/>
# <meta content="instagram://media?id=2088691469721473606" property="al:ios:url"/>
# <meta content="Instagram" property="al:android:app_name"/>
# <meta content="com.instagram.android" property="al:android:package"/>
# <meta content="https://www.instagram.com/p/Bz8hdNKIxJG/" property="al:android:url"/>
# <meta content="image" name="medium"/>
# <meta content="instapp:photo" property="og:type"/>
# <meta content="lipstick" property="instapp:hashtags"/><meta content="lip" property="instapp:hashtags"/><meta content="primers" property="instapp:hashtags"/><meta content="lash" property="instapp:hashtags"/><meta content="cosmetic" property="instapp:hashtags"/><meta content="crease" property="instapp:hashtags"/><meta content="glue" property="instapp:hashtags"/><meta content="foundation" property="instapp:hashtags"/><meta content="gloss" property="instapp:hashtags"/><meta content="tar" property="instapp:hashtags"/><meta content="lashes" property="instapp:hashtags"/><meta content="cosmetics" property="instapp:hashtags"/><meta content="glitter" property="instapp:hashtags"/><meta content="eyeshadow" property="instapp:hashtags"/><meta content="eyebrows" property="instapp:hashtags"/><meta content="mascara" property="instapp:hashtags"/><meta content="instamakeup" property="instapp:hashtags"/><meta content="beautiful" property="instapp:hashtags"/><meta content="toptags" property="instapp:hashtags"/><meta content="powder" property="instapp:hashtags"/><meta content="concealer" property="instapp:hashtags"/><meta content="fashion" property="instapp:hashtags"/><meta content="lips" property="instapp:hashtags"/><meta content="palettes" property="instapp:hashtags"/><meta content="eyeliner" property="instapp:hashtags"/><meta content="makeup" property="instapp:hashtags"/><meta content="eyes" property="instapp:hashtags"/><meta content="base" property="instapp:hashtags"/>
# <link href="android-app://com.instagram.android/https/instagram.com/p/Bz8hdNKIxJG/" rel="alternate">
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/" hreflang="x-default" rel="alternate">
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=en" hreflang="en" rel="alternate">
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=fr" hreflang="fr" rel="alternate">
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=it" hreflang="it" rel="alternate">
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=de" hreflang="de" rel="alternate">
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es" hreflang="es" rel="alternate">
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=zh-cn" hreflang="zh-cn" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=zh-tw" hreflang="zh-tw" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ja" hreflang="ja" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ko" hreflang="ko" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=pt" hreflang="pt" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=pt-br" hreflang="pt-br" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=af" hreflang="af" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=cs" hreflang="cs" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=da" hreflang="da" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=el" hreflang="el" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=fi" hreflang="fi" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=hr" hreflang="hr" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=hu" hreflang="hu" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=id" hreflang="id" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ms" hreflang="ms" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=nb" hreflang="nb" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=nl" hreflang="nl" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=pl" hreflang="pl" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ru" hreflang="ru" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=sk" hreflang="sk" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=sv" hreflang="sv" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=th" hreflang="th" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=tl" hreflang="tl" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=tr" hreflang="tr" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=hi" hreflang="hi" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=bn" hreflang="bn" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=gu" hreflang="gu" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=kn" hreflang="kn" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ml" hreflang="ml" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=mr" hreflang="mr" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=pa" hreflang="pa" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ta" hreflang="ta" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=te" hreflang="te" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ne" hreflang="ne" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=si" hreflang="si" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ur" hreflang="ur" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=vi" hreflang="vi" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=bg" hreflang="bg" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=fr-ca" hreflang="fr-ca" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=ro" hreflang="ro" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=sr" hreflang="sr" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=uk" hreflang="uk" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=zh-hk" hreflang="zh-hk" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-sv" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-pe" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-cr" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-ar" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-cl" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-pa" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-gt" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-bo" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-pr" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-py" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-cu" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-do" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-ni" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-uy" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-ve" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-hn" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-ec" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-mx" rel="alternate"/>
# <link href="https://www.instagram.com/p/Bz8hdNKIxJG/?hl=es-la" hreflang="es-co" rel="alternate"/>
# </link></link></link></link></link></link></link></meta></meta></meta>

# %%
user_links = ['https://www.instagram.com/',
 'https://www.instagram.com/moda2528/',
 'https://www.instagram.com/millydoesmakeup_/',
 'https://www.instagram.com/moda2528/',
 'https://www.instagram.com/dymeblock/',
 'https://www.instagram.com/belrosebeauty/',
 'https://www.instagram.com/belrosebeauty/',
 'https://www.instagram.com/nena/',
 'https://www.instagram.com/ofracosmetics/',
 'https://www.instagram.com/mimiartistry/',
 'https://www.instagram.com/athena.beauties/',
 'https://www.instagram.com/shop_hubb/',
 'https://www.instagram.com/sheesefashion/',
 'https://www.instagram.com/leonovgallery/',
 'https://www.instagram.com/nkknakha/',
 'https://www.instagram.com/sheesefashion/',
 'https://www.instagram.com/sheesefashion/',
 'https://www.instagram.com/moor_94/',
 'https://www.instagram.com/chikim6746/',
 'https://www.instagram.com/beautty_trends/',
 'https://www.instagram.com/',
 'https://www.instagram.com/little_angelshop1/',
 'https://www.instagram.com/arrozdefyesta/',
 'https://www.instagram.com/jessypdj/',
 'https://www.instagram.com/_dj_wa_/',
 'https://www.instagram.com/lady_ofmakeup/',
 'https://www.instagram.com/mecosmeticz/',
 'https://www.instagram.com/astridzhelgwin/',
 'https://www.instagram.com/makeup_by_melanie_k/',
 'https://www.instagram.com/quenbeautyshop_310793/',
 'https://www.instagram.com/mariaguadalupegarciacardenas/',
 'https://www.instagram.com/rubyred.mua/',
 'https://www.instagram.com/oldfullmoon/',
 'https://www.instagram.com/dr.eugene/',
 'https://www.instagram.com/___beautyangel__/',
 'https://www.instagram.com/rdlbencic_erj/',
 'https://www.instagram.com/shop_hubb/',
 'https://www.instagram.com/',
 'https://www.instagram.com/ggofficialshannen/',
 'https://www.instagram.com/ohneul_beauty/',
 'https://www.instagram.com/ggofficialshannen/',
 'https://www.instagram.com/',
 'https://www.instagram.com/_lumecolors/',
 'https://www.instagram.com/jegegkosmetik_bugbug/',
 'https://www.instagram.com/royaldynastycosmetics/',
 'https://www.instagram.com/makeup_in_australia/',
 'https://www.instagram.com/_lumecolors/',
 'https://www.instagram.com/ggofficialshannen/',
 'https://www.instagram.com/melissamarton.mua/',
 'https://www.instagram.com/patitovizcarra/',
 'https://www.instagram.com/beauty.bukareview/']

user_links
# Out:
# ['https://www.instagram.com/',
#  'https://www.instagram.com/moda2528/',
#  'https://www.instagram.com/millydoesmakeup_/',
#  'https://www.instagram.com/moda2528/',
#  'https://www.instagram.com/dymeblock/',
#  'https://www.instagram.com/belrosebeauty/',
#  'https://www.instagram.com/belrosebeauty/',
#  'https://www.instagram.com/nena/',
#  'https://www.instagram.com/ofracosmetics/',
#  'https://www.instagram.com/mimiartistry/',
#  'https://www.instagram.com/athena.beauties/',
#  'https://www.instagram.com/shop_hubb/',
#  'https://www.instagram.com/sheesefashion/',
#  'https://www.instagram.com/leonovgallery/',
#  'https://www.instagram.com/nkknakha/',
#  'https://www.instagram.com/sheesefashion/',
#  'https://www.instagram.com/sheesefashion/',
#  'https://www.instagram.com/moor_94/',
#  'https://www.instagram.com/chikim6746/',
#  'https://www.instagram.com/beautty_trends/',
#  'https://www.instagram.com/',
#  'https://www.instagram.com/little_angelshop1/',
#  'https://www.instagram.com/arrozdefyesta/',
#  'https://www.instagram.com/jessypdj/',
#  'https://www.instagram.com/_dj_wa_/',
#  'https://www.instagram.com/lady_ofmakeup/',
#  'https://www.instagram.com/mecosmeticz/',
#  'https://www.instagram.com/astridzhelgwin/',
#  'https://www.instagram.com/makeup_by_melanie_k/',
#  'https://www.instagram.com/quenbeautyshop_310793/',
#  'https://www.instagram.com/mariaguadalupegarciacardenas/',
#  'https://www.instagram.com/rubyred.mua/',
#  'https://www.instagram.com/oldfullmoon/',
#  'https://www.instagram.com/dr.eugene/',
#  'https://www.instagram.com/___beautyangel__/',
#  'https://www.instagram.com/rdlbencic_erj/',
#  'https://www.instagram.com/shop_hubb/',
#  'https://www.instagram.com/',
#  'https://www.instagram.com/ggofficialshannen/',
#  'https://www.instagram.com/ohneul_beauty/',
#  'https://www.instagram.com/ggofficialshannen/',
#  'https://www.instagram.com/',
#  'https://www.instagram.com/_lumecolors/',
#  'https://www.instagram.com/jegegkosmetik_bugbug/',
#  'https://www.instagram.com/royaldynastycosmetics/',
#  'https://www.instagram.com/makeup_in_australia/',
#  'https://www.instagram.com/_lumecolors/',
#  'https://www.instagram.com/ggofficialshannen/',
#  'https://www.instagram.com/melissamarton.mua/',
#  'https://www.instagram.com/patitovizcarra/',
#  'https://www.instagram.com/beauty.bukareview/']

# %%
#from urllib.request import urlopen

#req = requests.get('https://www.instagram.com/seduceme.pe/')
#sou = BeautifulSoup(req.content, 'html.parser')
#descript = (sou.find('script', attrs={'type': 'application/ld+json'})).string
#jscript = json.loads(descript)    
#jscript.get("description")

# %%
result=pd.DataFrame()
for i in range(len(links)):
    try:
        page = urlopen(links[i]).read()
        data=bs(page, 'html.parser')
        body = data.find('body')
        script = body.find('script')
        raw = script.text.strip().replace('window._sharedData =', '').replace(';', '')
        json_data=json.loads(raw)
        posts =json_data['entry_data']['PostPage'][0]['graphql']
        posts= json.dumps(posts)
        posts = json.loads(posts)
        x = pd.DataFrame.from_dict(json_normalize(posts), orient='columns') 
        x.columns =  x.columns.str.replace("shortcode_media.", "")
        result=result.append(x)
       
    except:
        np.nan
#Just check for the duplicates
result = result.drop_duplicates(subset = 'shortcode')
result.index = range(len(result.index))
sort=False

# %%
pd.concat([pd.DataFrame(links, columns=['Links']) for i in range(len(links))], ignore_index=False)
#pd.concat([pd.DataFrame(likes, columns=['Likes']) for i in range(len(links))], ignore_index=False)
#pd.concat([pd.DataFrame(comments, columns=['Comments']) for i in range(len(links))], ignore_index=False)

# %%
from selenium import webdriver

driver = webdriver.PhantomJS()
driver.get('https://www.instagram.com/accounts/login')
username = driver.find_element_by_xpath('//*[@name="username"]')
password = driver.find_element_by_xpath('//*[@name="password"]')
login_btn = driver.find_element_by_xpath('//*[@class="_aj7mu _taytv _ki5uo _o0442"]')

username.send_keys("username")
password.send_keys("password!")

#test to see if input values are reflecting
print(username.get_attribute('value'))
print(password.get_attribute('value'))

#login
login_btn.click()
logged_in_class = driver.find_elements_by_class_name("logged-in")
not_logged_in_class = driver.find_elements_by_class_name("not-logged-in")

#to check if logged-in or not-logged-in
print(len(logged_in_class))
print(len(not_logged_in_class))


driver.quit()

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re
import os
import requests
from urllib.request import urlopen
import json
from pandas.io.json import json_normalize
import pandas as pd, numpy as np
import argparse
import csv
from typing import List
from requests_html import HTMLSession

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys

links=[]  

class InstagramBot():
    def __init__(self, email, password):
        self.browser = webdriver.Chrome()
        self.email = email
        self.password = password
    
    def signIn(self):
        self.browser.get('https://www.instagram.com/accounts/login/')

        emailInput = self.browser.find_elements_by_css_selector('form input')[0]
        passwordInput = self.browser.find_elements_by_css_selector('form input')[1]

        emailInput.send_keys(self.email)
        passwordInput.send_keys(self.password)
        passwordInput.send_keys(Keys.ENTER)
        time.sleep(2)
        
    def hashtagexplore(self, hashtag):
        self.browser.get('https://www.instagram.com/explore/tags/'+hashtag)
        for i in range(0, 10):
            self.browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(5)

        source = browser.page_source
        data=bs(source, 'html.parser')
        body = data.find('body')
        script = body.find('span')

        for link in script.findAll('a'):
             if re.match("/p", link.get('href')):
                links.append('https://www.instagram.com'+link.get('href'))
        return links
    
bot = InstagramBot('529291731@qq.com', 'claytonhouse777')
bot.signIn()
bot.hashtagexplore('lipstick')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10992fc50>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-50-0ee26d51c7f6> in <module>
#      40 bot = InstagramBot('529291731@qq.com', 'claytonhouse777')
#      41 bot.signIn()
# ---> 42 bot.hashtagexplore('lipstick')
#      43
#
# <ipython-input-50-0ee26d51c7f6> in hashtagexplore(self, hashtag)
#      28             time.sleep(5)
#      29
# ---> 30         source = browser.page_source
#      31         data=bs(source, 'html.parser')
#      32         body = data.find('body')
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /anaconda3/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      66             return self.request_encode_url(method, url, fields=fields,
#      67                                            headers=headers,
# ---> 68                                            **urlopen_kw)
#      69         else:
#      70             return self.request_encode_body(method, url, fields=fields,
#
# /anaconda3/lib/python3.7/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      87             url += '?' + urlencode(fields)
#      88
# ---> 89         return self.urlopen(method, url, **extra_kw)
#      90
#      91     def request_encode_body(self, method, url, fields=None, headers=None,
#
# /anaconda3/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#     401         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=63539): Max retries exceeded with url: /session/7db01cadd6fb699edd29a0073ab91dcb/source (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10992fc50>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
source = browser.page_source
data=bs(source, 'html.parser')
body = data.find('body')
script = body.find('span')

for link in script.findAll('a'):
     if re.match("/p", link.get('href')):
        links.append('https://www.instagram.com'+link.get('href'))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x109908d68>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-53-b86f9d5a0d1d> in <module>
# ----> 1 source = browser.page_source
#       2 data=bs(source, 'html.parser')
#       3 body = data.find('body')
#       4 script = body.find('span')
#       5
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /anaconda3/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      66             return self.request_encode_url(method, url, fields=fields,
#      67                                            headers=headers,
# ---> 68                                            **urlopen_kw)
#      69         else:
#      70             return self.request_encode_body(method, url, fields=fields,
#
# /anaconda3/lib/python3.7/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      87             url += '?' + urlencode(fields)
#      88
# ---> 89         return self.urlopen(method, url, **extra_kw)
#      90
#      91     def request_encode_body(self, method, url, fields=None, headers=None,
#
# /anaconda3/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#     401         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=63539): Max retries exceeded with url: /session/7db01cadd6fb699edd29a0073ab91dcb/source (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x109908d68>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
links
# Out:
# []

# %%
def followWithUsername(self, username):
    self.browser.get('https://www.instagram.com/' + username + '/')
    time.sleep(2)
    followButton = self.browser.find_element_by_css_selector('button')
    if (followButton.text != 'Following'):
        followButton.click()
        time.sleep(2)
    else:
        print("You are already following this user")
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-23-e36f9ff03770> in <module>
#       5 links=[]
#       6 for i in range(0,10):
# ----> 7     browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#       8     time.sleep(2)
#       9
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=75.0.3770.100)

# %%
oglinks = ['https://www.instagram.com/p/Bz8hdNKIxJG/',
 'https://www.instagram.com/p/Bz9PsIyJGAi/',
 'https://www.instagram.com/p/Bz8eoK5HnAo/',
 'https://www.instagram.com/p/Bz8v-HUp5EM/']

def postscrapper(oglinks):
    for i in range(len(oglinks)):
        webpage_source = requests.get(str(oglinks[i])).text
        page_content = BeautifulSoup(webpage_source, 'html.parser')
        print(page_content)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4a392215afa9> in <module>
#       2  'https://www.instagram.com/p/Bz9PsIyJGAi/',
#       3  'https://www.instagram.com/p/Bz8eoK5HnAo/',
# ----> 4  'https://www.instagram.com/p/Bz8v-HUp5EM/')
#
# TypeError: postscrapper() takes 2 positional arguments but 4 were given
